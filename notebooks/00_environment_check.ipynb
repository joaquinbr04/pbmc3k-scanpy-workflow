# %% [markdown]
# # Environment check
#
# This notebook verifies that the computational environment for the PBMC3k project is correctly configured before starting the biological analysis.

# %%
import sys
from importlib.metadata import version

import scanpy as sc

print("Python executable:", sys.executable)
print("Python version:", sys.version.split()[0])
print("Scanpy version:", version("scanpy"))
# Out:
# Python executable: c:\Users\joaqu\miniforge3\envs\pbmc3k-scanpy\python.exe
# Python version: 3.12.14
# Scanpy version: 1.12.4
